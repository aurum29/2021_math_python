# %% [markdown]
# <a href="https://colab.research.google.com/github/zombe962/2021_math_python/blob/main/2021%ED%95%99%EB%85%84%EB%8F%84_9%EC%9B%94_%EB%AA%A8%EC%9D%98%ED%8F%89%EA%B0%802.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2021 학년도 9월 모의평가2
#
# ![image.png](data:image/png;base64,...)

# %%
from itertools import permutations as p
from fractions import Fraction as F
Group = ['M1', 'M2', 'S1', 'S2', 'S3', 'S4', 'S5']
All = list(p(Group))

Sun = [i for i in All if (i.index('M1') < i.index('M2')) or abs(i.index('M1') - i.index('M2')) == 3]

print(F(len(Sun),len(total_all)))
# Out:
# 25/42
