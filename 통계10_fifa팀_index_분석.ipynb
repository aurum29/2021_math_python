# %% [markdown]
# <a href="https://colab.research.google.com/github/zombe962/2021_math_python/blob/main/%ED%86%B5%EA%B3%8410_fifa%ED%8C%80_index_%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f1edb848-e51a-4090-ab3d-dd3646b269a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f1edb848-e51a-4090-ab3d-dd3646b269a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving FIFA 2018 Statistics.csv to FIFA 2018 Statistics.csv

# %%
pd.read_csv('FIFA 2018 Statistics.csv')
# Out:
#            Date          Team  ... Own goals  Own goal Time
# 0    14-06-2018        Russia  ...       NaN            NaN
# 1    14-06-2018  Saudi Arabia  ...       NaN            NaN
# 2    15-06-2018         Egypt  ...       NaN            NaN
# 3    15-06-2018       Uruguay  ...       NaN            NaN
# 4    15-06-2018       Morocco  ...       1.0           90.0
# ..          ...           ...  ...       ...            ...
# 123  11-07-2018       England  ...       NaN            NaN
# 124  14-07-2018       Belgium  ...       NaN            NaN
# 125  14-07-2018       England  ...       NaN            NaN
# 126  15-07-2018        France  ...       1.0           18.0
# 127  15-07-2018       Croatia  ...       NaN            NaN
#
# [128 rows x 27 columns]

# %%
fifa = pd.read_csv('FIFA 2018 Statistics.csv')

print(fifa.index)
print(fifa.columns)
print(len(fifa.columns))
# Out:
# RangeIndex(start=0, stop=128, step=1)
# Index(['Date', 'Team', 'Opponent', 'Goal Scored', 'Ball Possession %',
#        'Attempts', 'On-Target', 'Off-Target', 'Blocked', 'Corners', 'Offsides',
#        'Free Kicks', 'Saves', 'Pass Accuracy %', 'Passes',
#        'Distance Covered (Kms)', 'Fouls Committed', 'Yellow Card',
#        'Yellow & Red', 'Red', 'Man of the Match', '1st Goal', 'Round', 'PSO',
#        'Goals in PSO', 'Own goals', 'Own goal Time'],
#       dtype='object')
# 27

# %%
pd.set_option('display.max_rows', 200)  # 최대 줄수 설정
fifa[:]
# Out:
#            Date            Team  ... Own goals  Own goal Time
# 0    14-06-2018          Russia  ...       NaN            NaN
# 1    14-06-2018    Saudi Arabia  ...       NaN            NaN
# 2    15-06-2018           Egypt  ...       NaN            NaN
# 3    15-06-2018         Uruguay  ...       NaN            NaN
# 4    15-06-2018         Morocco  ...       1.0           90.0
# 5    15-06-2018            Iran  ...       NaN            NaN
# 6    15-06-2018        Portugal  ...       NaN            NaN
# 7    15-06-2018           Spain  ...       NaN            NaN
# 8    16-06-2018          France  ...       NaN            NaN
# 9    16-06-2018       Australia  ...       1.0           81.0
# 10   16-06-2018       Argentina  ...       NaN            NaN
# 11   16-06-2018         Iceland  ...       NaN            NaN
# 12   16-06-2018            Peru  ...       NaN            NaN
# 13   16-06-2018         Denmark  ...       NaN            NaN
# ...

# %%
fifa[1:4]
# Out:
#          Date          Team Opponent  ...  Goals in PSO  Own goals  Own goal Time
# 1  14-06-2018  Saudi Arabia   Russia  ...             0        NaN            NaN
# 2  15-06-2018         Egypt  Uruguay  ...             0        NaN            NaN
# 3  15-06-2018       Uruguay    Egypt  ...             0        NaN            NaN
#
# [3 rows x 27 columns]

# %%
fifa.head(3)    # 위부터 세번째
# Out:
#          Date          Team  ... Own goals  Own goal Time
# 0  14-06-2018        Russia  ...       NaN            NaN
# 1  14-06-2018  Saudi Arabia  ...       NaN            NaN
# 2  15-06-2018         Egypt  ...       NaN            NaN
#
# [3 rows x 27 columns]

# %%
fifa.tail(3)    # 밑에서 세번째
# Out:
#            Date     Team Opponent  ...  Goals in PSO  Own goals  Own goal Time
# 125  14-07-2018  England  Belgium  ...             0        NaN            NaN
# 126  15-07-2018   France  Croatia  ...             0        1.0           18.0
# 127  15-07-2018  Croatia   France  ...             0        NaN            NaN
#
# [3 rows x 27 columns]

# %%
fifateam = fifa.set_index('Team')

# %%
kor = fifateam.loc['Korea Republic']
kor
# Out:
#                       Date Opponent  ...  Own goals  Own goal Time
# Team                                 ...
# Korea Republic  18-06-2018   Sweden  ...        NaN            NaN
# Korea Republic  23-06-2018   Mexico  ...        NaN            NaN
# Korea Republic  27-06-2018  Germany  ...        NaN            NaN
#
# [3 rows x 26 columns]

# %%
kor.mean()
# Out:
# Goal Scored                 1.000000
# Ball Possession %          39.666667
# Attempts                   11.000000
# On-Target                   3.666667
# Off-Target                  3.000000
# Blocked                     4.333333
# Corners                     5.000000
# Offsides                    0.000000
# Free Kicks                 12.000000
# Saves                       4.333333
# Pass Accuracy %            78.333333
# Passes                    311.333333
# Distance Covered (Kms)    106.666667
# Fouls Committed            21.000000
# Yellow Card                 3.333333
# Yellow & Red                0.000000
# Red                         0.000000
# 1st Goal                   90.000000
# Goals in PSO                0.000000
# Own goals                        NaN
# Own goal Time                    NaN
# dtype: float64

# %%
kor.var()
# Out:
# Goal Scored                  1.000000
# Ball Possession %           82.333333
# Attempts                    36.000000
# On-Target                   10.333333
# Off-Target                   3.000000
# Blocked                     17.333333
# Corners                      4.000000
# Offsides                     0.000000
# Free Kicks                  61.000000
# Saves                        5.333333
# Pass Accuracy %             16.333333
# Passes                    4150.333333
# Distance Covered (Kms)     100.333333
# Fouls Committed             19.000000
# Yellow Card                  1.333333
# Yellow & Red                 0.000000
# Red                          0.000000
# 1st Goal                     0.000000
# Goals in PSO                 0.000000
# Own goals                         NaN
# Own goal Time                     NaN
# dtype: float64

# %%
kor.std()
# Out:
# Goal Scored                1.000000
# Ball Possession %          9.073772
# Attempts                   6.000000
# On-Target                  3.214550
# Off-Target                 1.732051
# Blocked                    4.163332
# Corners                    2.000000
# Offsides                   0.000000
# Free Kicks                 7.810250
# Saves                      2.309401
# Pass Accuracy %            4.041452
# Passes                    64.423081
# Distance Covered (Kms)    10.016653
# Fouls Committed            4.358899
# Yellow Card                1.154701
# Yellow & Red               0.000000
# Red                        0.000000
# 1st Goal                   0.000000
# Goals in PSO               0.000000
# Own goals                       NaN
# Own goal Time                   NaN
# dtype: float64

# %%
len(set(fifateam.index))    # 전체 팀의 갯수
# Out:
# 32

# %%
a = []     # 전체 팀의 갯수
for i in fifateam.index:
    if i not in a:
        a.append(i)

print(len(a))
# Out:
# 32
