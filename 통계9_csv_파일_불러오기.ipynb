# %% [markdown]
# <a href="https://colab.research.google.com/github/zombe962/2021_math_python/blob/main/%ED%86%B5%EA%B3%849_csv_%ED%8C%8C%EC%9D%BC_%EB%B6%88%EB%9F%AC%EC%98%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# google colab을 사용하고 있으므로
#
#
# ```
# from google.colab import files
# uploaded = files.upload()
# pd.read_csv('파일명')
# ```
#
# 을 해주어야 파일이 올라간다.

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-56d2cf99-132c-4de1-b907-e5ea1ff9d77e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-56d2cf99-132c-4de1-b907-e5ea1ff9d77e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving FIFA 2018 Statistics.csv to FIFA 2018 Statistics.csv

# %%
pd.read_csv('FIFA 2018 Statistics.csv')
# Out:
#            Date          Team  ... Own goals  Own goal Time
# 0    14-06-2018        Russia  ...       NaN            NaN
# 1    14-06-2018  Saudi Arabia  ...       NaN            NaN
# 2    15-06-2018         Egypt  ...       NaN            NaN
# 3    15-06-2018       Uruguay  ...       NaN            NaN
# 4    15-06-2018       Morocco  ...       1.0           90.0
# ..          ...           ...  ...       ...            ...
# 123  11-07-2018       England  ...       NaN            NaN
# 124  14-07-2018       Belgium  ...       NaN            NaN
# 125  14-07-2018       England  ...       NaN            NaN
# 126  15-07-2018        France  ...       1.0           18.0
# 127  15-07-2018       Croatia  ...       NaN            NaN
#
# [128 rows x 27 columns]
